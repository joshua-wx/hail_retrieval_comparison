# %%
import os
import glob
import pyart
import numpy as np
from pyhail import hsda, hdr, mesh, common
from cpol_processing import processing as cpol_prc
from datetime import datetime
from multiprocessing import Pool

import warnings
warnings.filterwarnings('ignore')
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# /g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/cpol_processing-1.0-py3.6.egg/cpol_processing/production.py:28: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-a831439e8511>", line 3, in <module>
#     import pyart
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/pyart/__init__.py", line 51, in <module>
#     from . import io
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/pyart/io/__init__.py", line 90, in <module>
#     from .output_to_geotiff import write_grid_geotiff
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/pyart/io/output_to_geotiff.py", line 18, in <module>
#     import matplotlib.pyplot as plt
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/g/data/en0/jss548/miniconda3/envs/radar/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()

# %%
#paths
vol_path         = '/g/data/kl02/jss548/hail-research/radar_data'
out_path         = '/g/data/kl02/jss548/hail-research/processed_data'
sonde_path       = '/g/data/kl02/jss548/hail-research/snding_data'
srtm_ffn         = '/g/data1a/kl02/jss548/hail-research/srtm/srtm_67_18_Brisbane/srtm_67_18.tif'


target_data      = [['66_20141127', 'YBBN_20141127_00.nc']]
#                     ['66_20171010', 'YBBN_20171010_00.nc'],
#                     ['66_20171026', 'YBBN_20171026_00.nc'],
#                     ['66_20171029', 'YBBN_20171029_00.nc'],
#                     ['66_20171030', 'YBBN_20171030_00.nc'],
#                     ['66_20171107', 'YBBN_20171107_00.nc'],
#                     ['66_20171209', 'YBBN_20171209_00.nc'],
#                     ['66_20171231', 'YBBN_20171231_00.nc'],
#                     ['66_20180101', 'YBBN_20180101_00.nc'],
#                     ['66_20180103', 'YBBN_20180103_00.nc'],
#                     ['66_20170922', 'YBBN_20170922_00.nc'],
#                     ['CP2_20141127', 'YBBN_20141127_00.nc'],
#                     ['CP2_20081116', 'YBBN_20081116_00.nc']]

#field names (used to map to radar object fields)
fieldn      = {'dbzh':'DBZH',
               'dbzh_corr':'DBZH_CORR',
               'zdr':'ZDR',
               'zdr_corr':'ZDR_CORR',
               'phi':'PHIDP',
               'phi_unfold':'PHI_UNF',
               'phi_bringi':'PHIDP_BRINGI',
               'kdp':'KDP',
               'kdp_bringi':'KDP_BRINGI',
               'rhv':'RHOHV',
               'ncp':'NCP',
               'a_dbz':'SPEC_ATT_REFL',
               'a_zdr':'SPEC_ATT_DIFF',
               'rhv_corr':'RHOHV_CORR',
               'temp':'TEMPERATURE',
               'alt':'HEIGHT',
               'snr':'SNR',
               'cbb':'CBB',
               'hca':'HCA',
               'hail_ke':'HAIL_KE',
               'shi':'SHI',
               'posh':'POSH',
               'mesh':'MESH',
               'hdr':'HDR',
               'hsda': 'HSDA'}

#hsda vars
hca_hail_idx = [9] #list of hail classe(s) indices in HCA
dzdr         = 0

#grid
grid_shape  = (41, 201, 201)
grid_limits = ((0, 20000), (-100000.0, 100000.0), (-100000.0, 100000.0))
grid_roi    = 2000

#multiprocessing
ncpu         = 8

#TODO
#Implement dzdr
#Implement beam blockage mapping

# %%
def calc_beam_blocking(radar_ffn, srtm_ffn):
    #load radar object
    try:
        if ".h5" in radar_ffn:
            radar = pyart.aux_io.read_odim_h5(radar_ffn)
        elif ".nc" or ".mdv" in radar_ffn:
            radar      = pyart.io.read(radar_ffn)
    except:
        print('file failed: ',radar_ffn)
        return None
    
    cbb_meta = common.beam_blocking(radar, srtm_ffn)
    
    return cbb_meta

# %%
def chunks(l, n):
    """
    Yield successive n-sized chunks from l.
    From http://stackoverflow.com/a/312464
    """
    for i in range(0, len(l), n):
        yield l[i:i + n]

# %%
def worker_dualpol(radar_file_name,out_path,sonde_ffn):
    ###########################################################
    # Load file
    ###########################################################
    #load radar object
    try:
        if ".h5" in radar_file_name:
            radar = pyart.aux_io.read_odim_h5(radar_file_name)
            radar_name = radar.metadata['source'][6:8]
        elif ".nc" or ".mdv" in radar_file_name:
            radar      = pyart.io.read(radar_file_name)
            radar_name = radar.metadata['instrument_name'][0:3]
    except:
        print('file failed: ',radar_file_name)
        return None
    
    #extract date    
    date_str = radar.time['units'][-20:]
    dt       = datetime.strptime(date_str, '%Y-%m-%dT%H:%M:%SZ')    

    #fix field names
    radar.add_field(fieldn['dbzh'], radar.fields.pop('reflectivity'))
    radar.add_field(fieldn['zdr'], radar.fields.pop('differential_reflectivity'))
    radar.add_field(fieldn['phi'], radar.fields.pop('differential_phase'))
    radar.add_field(fieldn['kdp'], radar.fields.pop('specific_differential_phase'))
    radar.add_field(fieldn['rhv'], radar.fields.pop('cross_correlation_ratio'))
    try:
        radar.add_field(fieldn['ncp'], radar.fields.pop('normalized_coherent_power'))
    except:
        pass
    
    #add cbb data
    radar.add_field(fieldn['cbb'], cbb_meta, replace_existing=True)
    
    ###########################################################
    # Filtering
    ###########################################################
    
    #rhohv gatefilter
    gatefilter = pyart.filters.GateFilter(radar)
    gatefilter.exclude_below(fieldn['rhv'], 0.7)
    
    #rhohv texture filtering
    #gatefilter = pyart.filters.moment_and_texture_based_gate_filter(
    
    ###########################################################
    # Correction
    ###########################################################
    
    #build temp information
    height, temperature, snr = cpol_prc.radar_codes.snr_and_sounding(radar, sonde_ffn, refl_field_name=fieldn['dbzh'], 
                                                                     temp_field_name = 'temp') #temp from radiosonde nc
    radar.add_field(fieldn['temp'], temperature, replace_existing=True)
    radar.add_field(fieldn['alt'], height, replace_existing=True)
    radar.add_field(fieldn['snr'], snr, replace_existing=True)
    
    #add NCP if it doesn't exist
    try:
        radar.fields[fieldn['ncp']]
        fake_ncp = False
    except KeyError:
        # Creating a fake NCP field.
        ncp = pyart.config.get_metadata('normalized_coherent_power')
        emr2 = np.zeros_like(snr['data'])
        emr2[snr['data'] > 7.5] = 1
        ncp['data'] = emr2
        ncp['description'] = "THIS FIELD IS FAKE. SHOULD BE REMOVED!"
        radar.add_field(fieldn['ncp'], ncp)
        fake_ncp = True
    
    #RHOHV Noise correct
    rho_corr = cpol_prc.radar_codes.correct_rhohv(radar, rhohv_name=fieldn['rhv'], snr_name=fieldn['snr'])
    radar.add_field_like(fieldn['rhv'], fieldn['rhv_corr'], rho_corr, replace_existing=True)
    
    #ZDR Noise Correct
    corr_zdr = cpol_prc.radar_codes.correct_zdr(radar, zdr_name=fieldn['zdr'], snr_name=fieldn['snr'])
    radar.add_field_like(fieldn['zdr'], fieldn['zdr_corr'], corr_zdr, replace_existing=True)
    
    #unfold phidp
    phi_unfold = cpol_prc.phase.unfold_raw_phidp(radar, refl_field=fieldn['dbzh'], ncp_field=fieldn['ncp'], 
                                                 rhv_field=fieldn['rhv_corr'], phi_name=fieldn['phi'])
    radar.add_field(fieldn['phi_unfold'], phi_unfold, replace_existing=True)

    #recalculate phidp
    phimeta, kdpmeta = cpol_prc.phase.phidp_bringi(radar, gatefilter, refl_field=fieldn['dbzh'], ncp_name=fieldn['ncp'], 
                                                   rhohv_name=fieldn['rhv_corr'], unfold_phidp_name=fieldn['phi_unfold'])
    radar.add_field(fieldn['phi_bringi'], phimeta, replace_existing=True)
    radar.add_field(fieldn['kdp_bringi'], kdpmeta, replace_existing=True)
    radar.fields[fieldn['phi_bringi']]['long_name'] = "corrected_differential_phase"
    radar.fields[fieldn['kdp_bringi']]['long_name'] = "corrected_specific_differential_phase"

    ###########################################################
    # Attenuation
    ###########################################################
    
    #ZH attenuation correction
    atten_spec, zh_corr = cpol_prc.attenuation.correct_attenuation_zh_pyart(radar, refl_field=fieldn['dbzh'], ncp_field=fieldn['ncp'], 
                                                                            rhv_field=fieldn['rhv_corr'], phidp_field=fieldn['kdp_bringi'])
    radar.add_field(fieldn['dbzh_corr'], zh_corr, replace_existing=True)
    radar.add_field(fieldn['a_dbz'], atten_spec, replace_existing=True)    
    
    #ZDR attenuation correction
    atten_spec_zdr, zdr_corr = cpol_prc.attenuation.correct_attenuation_zdr(radar, zdr_name=fieldn['zdr_corr'], kdp_name=fieldn['kdp_bringi'], 
                                                                            alpha=0.016)
    radar.add_field_like(fieldn['zdr'], fieldn['zdr_corr'], zdr_corr, replace_existing=True)
    radar.add_field(fieldn['a_zdr'], atten_spec_zdr,
                    replace_existing=True)
    
    ###########################################################
    # Apply filter
    ###########################################################
    
    #apply rhohv filter
    radar.fields[fieldn['dbzh_corr']]['data']   = cpol_prc.filtering.filter_hardcoding(radar.fields[fieldn['dbzh_corr']]['data'], gatefilter)
    radar.fields[fieldn['zdr_corr']]['data']   = cpol_prc.filtering.filter_hardcoding(radar.fields[fieldn['zdr_corr']]['data'], gatefilter)
    radar.fields[fieldn['kdp_bringi']]['data'] = cpol_prc.filtering.filter_hardcoding(radar.fields[fieldn['kdp_bringi']]['data'], gatefilter)
    radar.fields[fieldn['rhv_corr']]['data']      = cpol_prc.filtering.filter_hardcoding(radar.fields[fieldn['rhv_corr']]['data'], gatefilter)
    
    ###########################################################
    # Classifications
    ###########################################################
    
    #CSU HCA
    hydro_class = cpol_prc.hydrometeors.hydrometeor_classification(radar, refl_name=fieldn['dbzh_corr'], zdr_name=fieldn['zdr_corr'], 
                                                                   kdp_name=fieldn['kdp_bringi'], rhohv_name=fieldn['rhv_corr'], 
                                                                   height_name=fieldn['alt'], temperature_name=fieldn['temp'])
    radar.add_field(fieldn['hca'], hydro_class, replace_existing=True)    
    
    #HSDA
    hsda_meta = hsda.main(radar, sonde_ffn, hca_hail_idx, dzdr, ref_name=fieldn['dbzh_corr'], zdr_name=fieldn['zdr_corr'], 
                                                                rhv_name=fieldn['rhv_corr'], phi_name=fieldn['phi_bringi'],
                                                                snr_name=fieldn['snr'], cbb_name=fieldn['cbb'],
                                                                hca_name=fieldn['hca'])
    
    #HDR
    hdr_meta = hdr.main(radar, ref_name=fieldn['dbzh_corr'], zdr_name=fieldn['zdr_corr'])
    radar.add_field(fieldn['hdr'], hdr_meta, replace_existing=True)
    
    ###########################################################
    # CFradial output
    ###########################################################
    
    # Removing fake and useless fields.
    if fake_ncp:
        radar.fields.pop(fieldn['ncp'])
    
    #write radar object to file
    out_fn  = '_'.join([radar_name, dt.strftime('%Y%m%d_%H%M%S'), 'processed']) + '.nc'
    out_ffn = '/'.join([out_path, out_fn])
    try:
        os.remove(out_ffn)
    except OSError:
        pass  
    pyart.io.write_cfradial(out_ffn, radar)
    
    print('completed volume ' + out_ffn)
    
    ###########################################################
    # Gridded Processing and Output
    ###########################################################
    
    out_fn  = '_'.join([radar_name, dt.strftime('%Y%m%d_%H%M%S'), 'meshgrids']) + '.nc'
    out_ffn = '/'.join([out_path,out_fn])
    try:
        os.remove(out_ffn)
    except OSError:
        pass
    
    #genreate grid object for cts fields
    grid = pyart.map.grid_from_radars(
        radar,
        grid_shape = grid_shape,
        grid_limits = grid_limits,
        weighting_function = 'Barnes',
        gridding_algo = 'map_gates_to_grid',
        roi_func='constant', constant_roi = grid_roi,
        fields=[fieldn['dbzh_corr'], fieldn['zdr_corr'], 
               fieldn['kdp_bringi'], fieldn['rhv_corr'],
               fieldn['hdr'], fieldn['temp'], fieldn['alt']])
    #generate grid object for discrete fields (using nearest neighbour)
    
    import time
    start_time = time.time()
    
    grid_dis = pyart.map.grid_from_radars(
        radar,
        grid_shape = grid_shape,
        grid_limits = grid_limits,
        weighting_function = 'Nearest',
        gridding_algo = 'map_to_grid',
        roi_func='constant', constant_roi = 1000,
        fields=[fieldn['hsda'], fieldn['hca']])    
    
    print("--- %s seconds ---" % (time.time() - start_time))

    
    #add discrete gridded fields into master grid object
    hca_grid  = grid_dis.fields[fieldn['hca']]
    hsda_grid = grid_dis.fields[fieldn['hsda']]
    grid.add_field(fieldn['hca'], hca_grid, replace_existing=True) 
    grid.add_field(fieldn['hsda'], hsda_grid, replace_existing=True) 
    
    #MESH
    _ = mesh.main(grid, fieldn, out_ffn, sonde_ffn, [], ref_name=fieldn['dbzh_corr'], save_flag=True)
    
    print('completed grid ' + out_ffn)
    
    return None

# %%
def worker_singlepol(radar_file_name,out_path,sonde_ffn):
    ###########################################################
    # Load file
    ###########################################################
    #load radar object
    try:
        if ".h5" in radar_file_name:
            radar = pyart.aux_io.read_odim_h5(radar_file_name)
            radar_name = radar.metadata['source'][6:8]
        elif ".nc" or ".mdv" in radar_file_name:
            radar      = pyart.io.read(radar_file_name)
            radar_name = radar.metadata['instrument_name'][0:3]
    except:
        print('file failed: ',radar_file_name)
        return None
    
    #extract date    
    date_str = radar.time['units'][-20:]
    dt       = datetime.strptime(date_str, '%Y-%m-%dT%H:%M:%SZ')    

    #fix field names
    radar.add_field(fieldn['dbzh'], radar.fields.pop('reflectivity'))
    
    ###########################################################
    # Gridded Processing and Output
    ###########################################################
    
    out_fn  = '_'.join([radar_name, dt.strftime('%Y%m%d_%H%M%S'), 'meshgrids']) + '.nc'
    out_ffn = '/'.join([out_path,out_fn])
    try:
        os.remove(out_ffn)
    except OSError:
        pass
    
    #genreate grid object for cts fields
    grid = pyart.map.grid_from_radars(
        radar,
        grid_shape = grid_shape,
        grid_limits = grid_limits,
        weighting_function = 'Barnes',
        gridding_algo = 'map_gates_to_grid',
        roi_func='constant', constant_roi = grid_roi,
        fields=[fieldn['dbzh']])
    #generate grid object for discrete fields (using nearest neighbour)
    
    #MESH
    _ = mesh.main(grid, fieldn, out_ffn, sonde_ffn, [], ref_name=fieldn['dbzh'], save_flag=True)
    
    print('completed grid ' + out_ffn)
    
    return None

# %%
#loop through target folders
for data_pair in target_data:
    #radar in/out data
    data_in_path   = '/'.join([vol_path, data_pair[0]])
    data_out_path  = '/'.join([out_path, data_pair[0]])
    if not os.path.exists(data_out_path):
            os.makedirs(data_out_path)
            
    #sonde file name
    sonde_ffn        = '/'.join([sonde_path, data_pair[1]])
    
    #index vol files
    vol_filelist = sorted(glob.glob(data_in_path + '/*'))

    print()
    
    # Cutting the file list into smaller chunks. (The multiprocessing.Pool instance
    # is freed from memory, at each iteration of the main for loop).
    chunked_list = chunks(vol_filelist, ncpu)
    i            = 0
    n_files      = len(vol_filelist)
    #loop through chunks
    for one_slice in chunked_list:
        args_list = [(onefile, data_out_path, sonde_ffn) for onefile in one_slice]
        with Pool(ncpu) as pool:
            pool.starmap(worker_singlepol, args_list)
            #update user
            i += ncpu
            print('processed: ' + str(round(i/n_files*100,2)))
        
print('finished')
# Out:
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_003630_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_000029_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_001830_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_003030_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_004230_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_002430_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_000630_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_001229_meshgrids.nc
# processed: 3.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_011830_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_013102_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_004830_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_010631_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_011230_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_010030_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_012430_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_005430_meshgrids.nc
# processed: 6.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_013630_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_021230_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_021830_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_014230_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_015430_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_020631_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_020030_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_014830_meshgrids.nc
# processed: 10.0
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_022430_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_023031_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_025431_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_023631_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_030031_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_024230_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_030632_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_024830_meshgrids.nc
# processed: 13.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_031231_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_035431_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_031831_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_032431_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_033031_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_033631_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_034231_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_034831_meshgrids.nc
# processed: 16.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_040031_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_043031_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_043631_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_040632_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_041231_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_041831_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_042431_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_044231_meshgrids.nc
# processed: 20.0
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_044831_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_050032_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_045431_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_051232_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_051831_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_053032_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_050633_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_052431_meshgrids.nc
# processed: 23.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_054304_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_053632_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_061232_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_055432_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_060633_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_054832_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_054232_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_060032_meshgrids.nc
# processed: 26.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_061832_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_070032_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_063632_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_062432_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_063032_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_064832_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_064232_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_065432_meshgrids.nc
# processed: 30.0
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_070634_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_074233_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_072432_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_071232_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_071832_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_073032_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_073632_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_074832_meshgrids.nc
# processed: 33.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_075433_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_080634_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_081233_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_083033_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_081833_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_080033_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_083633_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_082433_meshgrids.nc
# processed: 36.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_084233_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_090033_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_085433_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_092433_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_090634_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_084833_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_091833_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_091233_meshgrids.nc
# processed: 40.0
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_093033_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_100635_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_100034_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_095433_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_094834_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_101234_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_094233_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_093634_meshgrids.nc
# processed: 43.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_101833_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_103634_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_103034_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_102434_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_110034_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_104234_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_104834_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_105434_meshgrids.nc
# processed: 46.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_110635_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_113034_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_111234_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_114834_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_114234_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_112434_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_113634_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_111834_meshgrids.nc
# processed: 50.0
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_115434_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_123035_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_120034_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_123635_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_121835_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_122435_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_121235_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_120636_meshgrids.nc
# processed: 53.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_124235_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_131235_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_124835_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_132435_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_125435_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_130636_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_130035_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_131835_meshgrids.nc
# processed: 56.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_133035_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_141235_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_140637_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_134235_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_140035_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_133635_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_135435_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_134835_meshgrids.nc
# processed: 60.0
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_143635_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_145436_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_144836_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_144236_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_141835_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_150036_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_142435_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_143035_meshgrids.nc
# processed: 63.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_155436_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_151236_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_154836_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_153636_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_153036_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_154236_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_152436_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_151836_meshgrids.nc
# processed: 66.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_160036_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_160637_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_163636_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_162436_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_161836_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_163036_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_161236_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_164236_meshgrids.nc
# processed: 70.0
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_164837_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_171837_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_170037_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_170638_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_171237_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_172437_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_173037_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_165436_meshgrids.nc
# processed: 73.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_173637_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_181837_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_175437_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_174837_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_180037_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_174237_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_180638_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_181237_meshgrids.nc
# processed: 76.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_182437_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_190638_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_183037_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_184837_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_184237_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_183637_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_190037_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_185437_meshgrids.nc
# processed: 80.0
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_191238_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_192437_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_195438_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_194238_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_193038_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_193637_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_191837_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_194838_meshgrids.nc
# processed: 83.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_200038_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_201838_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_201238_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_204238_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_203038_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_200639_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_203638_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_202438_meshgrids.nc
# processed: 86.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_204838_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_210641_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_213040_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_211817_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_212418_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_210016_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_211239_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_205416_meshgrids.nc
# processed: 90.0
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_213641_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_220042_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_221843_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_214219_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_221220_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_214819_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_220641_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_215442_meshgrids.nc
# processed: 93.33
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_222443_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_223621_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_224244_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_230624_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_224844_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_225422_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_223021_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_230023_meshgrids.nc
# processed: 96.67
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_231822_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_234823_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_235423_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_231223_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_232423_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_233623_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_233023_meshgrids.nc
# completed grid /g/data/kl02/jss548/hail-research/processed_data/66_20141127/66_20141127_234223_meshgrids.nc
# processed: 100.0
# finished
